# %%
from matplotlib import pyplot as plt

from cuticulus.datasets import RoughSmoothFull

# %%
ds = RoughSmoothFull(size=(512, 512))
ds.images.shape, ds.labels.shape
# Out:
# [19:28:26] Loaded labels.                                                       ]8;id=807788;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py\builder.py]8;;\:]8;id=942944;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py#89\89]8;;\
# [19:28:28] Loaded dataset.                                                     ]8;id=383859;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py\builder.py]8;;\:]8;id=767331;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py#114\114]8;;\
#            Unique images considered: 2499                                      ]8;id=504872;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py\builder.py]8;;\:]8;id=764662;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py#135\135]8;;\
#            Samples per class:                                                  ]8;id=54856;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py\builder.py]8;;\:]8;id=416704;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py#128\128]8;;\
#            0: 1068                                                             ]8;id=560446;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py\builder.py]8;;\:]8;id=59359;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py#131\131]8;;\
#            1: 1431                                                             ]8;id=620103;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py\builder.py]8;;\:]8;id=974549;file:///home/noah/projects/cuticulus/cuticulus/core/datasets/builder.py#131\131]8;;\
# ((2499, 512, 512, 3), (2499,))

# %%
plt.imshow(ds.get_image(1))

# %%
ds.get_label(1)
# Out:
# 1
